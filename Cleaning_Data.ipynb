# %%
import pandas as pd
import numpy as np

# %%
# Loading in the dataset

file_path = "./Data/NYPD_Arrests_Data__Historic_.csv"

etl_df = pd.read_csv(file_path)

etl_df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                           PD_DESC  KY_CD  \
# 0   159838726  01/01/2017  115.0           RECKLESS ENDANGERMENT 2  355.0
# 1   159824786  01/01/2017  101.0                         ASSAULT 3  344.0
# 2   159840237  01/01/2017  729.0  FORGERY,ETC.,UNCLASSIFIED-FELONY  113.0
# 3   159828861  01/01/2017  744.0                    BAIL JUMPING 3  359.0
# 4   159834533  01/01/2017  203.0              TRESPASS 3, CRIMINAL  352.0
#
#                                 OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0             OFFENSES AGAINST THE PERSON  PL 1202000          M           M
# 1            ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           M
# 2                                 FORGERY  PL 1702500          F           B
# 3  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2155500          M           K
# 4                       CRIMINAL TRESPASS  PL 1401000          M           K
#
# ...

# %%
# Removing Arrest_Key, Law_Code, X_COORD_CD, Y_COORD_CD, Zip Codes, Community Districts, Borough Boundaries, City Council Districts columns.

etl_df.drop(columns=['ARREST_KEY', 'LAW_CODE', 'X_COORD_CD', 'Y_COORD_CD', 'Zip Codes', 'Community Districts', 'Borough Boundaries', 'City Council Districts'], axis=1)
# Out:
#         ARREST_DATE  PD_CD                                    PD_DESC  KY_CD  \
# 0        01/01/2017  115.0                    RECKLESS ENDANGERMENT 2  355.0
# 1        01/01/2017  101.0                                  ASSAULT 3  344.0
# 2        01/01/2017  729.0           FORGERY,ETC.,UNCLASSIFIED-FELONY  113.0
# 3        01/01/2017  744.0                             BAIL JUMPING 3  359.0
# 4        01/01/2017  203.0                       TRESPASS 3, CRIMINAL  352.0
# ...             ...    ...                                        ...    ...
# 1043530  12/31/2021  792.0                   WEAPONS POSSESSION 1 & 2  118.0
# 1043531  12/31/2021  101.0                                  ASSAULT 3  344.0
# 1043532  12/31/2021  439.0  LARCENY,GRAND FROM OPEN AREAS, UNATTENDED  109.0
# 1043533  12/31/2021  109.0                   ASSAULT 2,1,UNCLASSIFIED  106.0
# 1043534  12/31/2021  198.0                        CRIMINAL CONTEMPT 1  126.0
#
# ...
