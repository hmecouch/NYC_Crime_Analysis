# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# load data into a dataframe
df = pd.read_csv('Data/NYPD_Arrests_Data__Historic_.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                           PD_DESC  KY_CD  \
# 0   159838726  01/01/2017  115.0           RECKLESS ENDANGERMENT 2  355.0
# 1   159824786  01/01/2017  101.0                         ASSAULT 3  344.0
# 2   159840237  01/01/2017  729.0  FORGERY,ETC.,UNCLASSIFIED-FELONY  113.0
# 3   159828861  01/01/2017  744.0                    BAIL JUMPING 3  359.0
# 4   159834533  01/01/2017  203.0              TRESPASS 3, CRIMINAL  352.0
#
#                                 OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0             OFFENSES AGAINST THE PERSON  PL 1202000          M           M
# 1            ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           M
# 2                                 FORGERY  PL 1702500          F           B
# 3  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2155500          M           K
# 4                       CRIMINAL TRESPASS  PL 1401000          M           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0               14                  0     18-24        M           WHITE
# 1               18                  0     25-44        M           WHITE
# 2               40                  0     25-44        M  WHITE HISPANIC
# 3               67                  0     25-44        M           BLACK
# 4               60                  0     18-24        M           BLACK
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0    988912.0    212647.0  40.750350 -73.983175
# 1    992043.0    217246.0  40.762971 -73.971870
# 2   1006669.0    233631.0  40.807919 -73.919017
# 3   1009039.0    176368.0  40.650740 -73.910667
# 4    986229.0    148311.0  40.573763 -73.992878
#
#                                          Lon_Lat  Zip Codes  \
# 0  POINT (-73.98317545899994 40.750350440000034)    12080.0
# 1   POINT (-73.97186979099996 40.76297132000008)    12419.0
# 2   POINT (-73.91901728199997 40.80791877300004)    10932.0
# 3  POINT (-73.91066707899995 40.650739599000076)    13827.0
# 4  POINT (-73.99287775699997 40.573763375000055)    18184.0
#
#    Community Districts  Borough Boundaries  City Council Districts  \
# 0                 11.0                 4.0                    51.0
# 1                 11.0                 4.0                    51.0
# 2                 49.0                 5.0                    35.0
# 3                 61.0                 2.0                    25.0
# 4                 21.0                 2.0                    45.0
#
#    Police Precincts
# 0               8.0
# 1              10.0
# 2              23.0
# 3              40.0
# 4              35.0

# %%
# check for null values
df.isna().sum()
# Out:
# ARREST_KEY                   0
# ARREST_DATE                  0
# PD_CD                      162
# PD_DESC                   2031
# KY_CD                     2031
# OFNS_DESC                 2031
# LAW_CODE                    45
# LAW_CAT_CD                7411
# ARREST_BORO                  0
# ARREST_PRECINCT              0
# JURISDICTION_CODE            0
# AGE_GROUP                    0
# PERP_SEX                     0
# PERP_RACE                    0
# X_COORD_CD                   0
# Y_COORD_CD                   0
# Latitude                     0
# Longitude                    0
# Lon_Lat                      0
# Zip Codes                 2568
# Community Districts        161
# Borough Boundaries         164
# City Council Districts     161
# Police Precincts           162
# dtype: int64

# %%
# drop null values 
df.dropna(inplace=True)
df.isna().sum()
# Out:
# ARREST_KEY                0
# ARREST_DATE               0
# PD_CD                     0
# PD_DESC                   0
# KY_CD                     0
# OFNS_DESC                 0
# LAW_CODE                  0
# LAW_CAT_CD                0
# ARREST_BORO               0
# ARREST_PRECINCT           0
# JURISDICTION_CODE         0
# AGE_GROUP                 0
# PERP_SEX                  0
# PERP_RACE                 0
# X_COORD_CD                0
# Y_COORD_CD                0
# Latitude                  0
# Longitude                 0
# Lon_Lat                   0
# Zip Codes                 0
# Community Districts       0
# Borough Boundaries        0
# City Council Districts    0
# Police Precincts          0
# dtype: int64

# %%
# inspect the data types
df.dtypes
# Out:
# ARREST_KEY                  int64
# ARREST_DATE                object
# PD_CD                     float64
# PD_DESC                    object
# KY_CD                     float64
# OFNS_DESC                  object
# LAW_CODE                   object
# LAW_CAT_CD                 object
# ARREST_BORO                object
# ARREST_PRECINCT             int64
# JURISDICTION_CODE           int64
# AGE_GROUP                  object
# PERP_SEX                   object
# PERP_RACE                  object
# X_COORD_CD                float64
# Y_COORD_CD                float64
# Latitude                  float64
# Longitude                 float64
# Lon_Lat                    object
# Zip Codes                 float64
# Community Districts       float64
# Borough Boundaries        float64
# City Council Districts    float64
# Police Precincts          float64
# dtype: object

# %%
# change data types of columns
df['ARREST_DATE'] = pd.to_datetime(df['ARREST_DATE'], format="%m/%d/%Y")
df = df.astype({'PD_CD': int, 'KY_CD': int, 'Zip Codes': int, 'Community Districts': int, 
                'Borough Boundaries': int, 'City Council Districts': int, 'Police Precincts': int})

# %%
df.dtypes
# Out:
# ARREST_KEY                         int64
# ARREST_DATE               datetime64[ns]
# PD_CD                              int32
# PD_DESC                           object
# KY_CD                              int32
# OFNS_DESC                         object
# LAW_CODE                          object
# LAW_CAT_CD                        object
# ARREST_BORO                       object
# ARREST_PRECINCT                    int64
# JURISDICTION_CODE                  int64
# AGE_GROUP                         object
# PERP_SEX                          object
# PERP_RACE                         object
# X_COORD_CD                       float64
# Y_COORD_CD                       float64
# Latitude                         float64
# Longitude                        float64
# Lon_Lat                           object
# Zip Codes                          int32
# Community Districts                int32
# Borough Boundaries                 int32
# City Council Districts             int32
# Police Precincts                   int32
# dtype: object

# %%
# add day, month, and year columns using the dt accessor
df['day'] = df['ARREST_DATE'].dt.day
df['month'] = df['ARREST_DATE'].dt.month
df['year'] = df['ARREST_DATE'].dt.year
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                           PD_DESC  KY_CD  \
# 0   159838726  2017-01-01    115           RECKLESS ENDANGERMENT 2    355
# 1   159824786  2017-01-01    101                         ASSAULT 3    344
# 2   159840237  2017-01-01    729  FORGERY,ETC.,UNCLASSIFIED-FELONY    113
# 3   159828861  2017-01-01    744                    BAIL JUMPING 3    359
# 4   159834533  2017-01-01    203              TRESPASS 3, CRIMINAL    352
#
#                                 OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0             OFFENSES AGAINST THE PERSON  PL 1202000          M           M
# 1            ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           M
# 2                                 FORGERY  PL 1702500          F           B
# 3  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2155500          M           K
# 4                       CRIMINAL TRESPASS  PL 1401000          M           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0               14                  0     18-24        M           WHITE
# 1               18                  0     25-44        M           WHITE
# 2               40                  0     25-44        M  WHITE HISPANIC
# 3               67                  0     25-44        M           BLACK
# 4               60                  0     18-24        M           BLACK
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0    988912.0    212647.0  40.750350 -73.983175
# 1    992043.0    217246.0  40.762971 -73.971870
# 2   1006669.0    233631.0  40.807919 -73.919017
# 3   1009039.0    176368.0  40.650740 -73.910667
# 4    986229.0    148311.0  40.573763 -73.992878
#
#                                          Lon_Lat  Zip Codes  \
# 0  POINT (-73.98317545899994 40.750350440000034)      12080
# 1   POINT (-73.97186979099996 40.76297132000008)      12419
# 2   POINT (-73.91901728199997 40.80791877300004)      10932
# 3  POINT (-73.91066707899995 40.650739599000076)      13827
# 4  POINT (-73.99287775699997 40.573763375000055)      18184
#
#    Community Districts  Borough Boundaries  City Council Districts  \
# 0                   11                   4                      51
# 1                   11                   4                      51
# 2                   49                   5                      35
# 3                   61                   2                      25
# 4                   21                   2                      45
#
#    Police Precincts  day  month  year
# 0                 8    1      1  2017
# 1                10    1      1  2017
# 2                23    1      1  2017
# 3                40    1      1  2017
# 4                35    1      1  2017

# %%
# create new df with the columns that will be most important for this analysis
arrests = ['ARREST_KEY', 'ARREST_DATE', 'day', 'month', 'year', 'PD_DESC', 'OFNS_DESC', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT', 
           'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'Latitude', 'Longitude', 'Lon_Lat']
arrests_df = df[arrests]
arrests_df.head()
# Out:
#    ARREST_KEY ARREST_DATE  day  month  year                           PD_DESC  \
# 0   159838726  2017-01-01    1      1  2017           RECKLESS ENDANGERMENT 2
# 1   159824786  2017-01-01    1      1  2017                         ASSAULT 3
# 2   159840237  2017-01-01    1      1  2017  FORGERY,ETC.,UNCLASSIFIED-FELONY
# 3   159828861  2017-01-01    1      1  2017                    BAIL JUMPING 3
# 4   159834533  2017-01-01    1      1  2017              TRESPASS 3, CRIMINAL
#
#                                 OFNS_DESC LAW_CAT_CD ARREST_BORO  \
# 0             OFFENSES AGAINST THE PERSON          M           M
# 1            ASSAULT 3 & RELATED OFFENSES          M           M
# 2                                 FORGERY          F           B
# 3  OFFENSES AGAINST PUBLIC ADMINISTRATION          M           K
# 4                       CRIMINAL TRESPASS          M           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0               14                  0     18-24        M           WHITE
# 1               18                  0     25-44        M           WHITE
# 2               40                  0     25-44        M  WHITE HISPANIC
# 3               67                  0     25-44        M           BLACK
# 4               60                  0     18-24        M           BLACK
#
#     Latitude  Longitude                                        Lon_Lat
# 0  40.750350 -73.983175  POINT (-73.98317545899994 40.750350440000034)
# 1  40.762971 -73.971870   POINT (-73.97186979099996 40.76297132000008)
# 2  40.807919 -73.919017   POINT (-73.91901728199997 40.80791877300004)
# 3  40.650740 -73.910667  POINT (-73.91066707899995 40.650739599000076)
# 4  40.573763 -73.992878  POINT (-73.99287775699997 40.573763375000055)

# %%
# add the other columns into a reference df incase we need this data at some point
refs = ['ARREST_KEY', 'KY_CD', 'LAW_CODE', 'X_COORD_CD', 'Y_COORD_CD', 'Zip Codes', 
        'Community Districts', 'Borough Boundaries', 'City Council Districts', 'Police Precincts']
refs_df = df[refs]
refs_df.head()
# Out:
#    ARREST_KEY  KY_CD    LAW_CODE  X_COORD_CD  Y_COORD_CD  Zip Codes  \
# 0   159838726    355  PL 1202000    988912.0    212647.0      12080
# 1   159824786    344  PL 1200001    992043.0    217246.0      12419
# 2   159840237    113  PL 1702500   1006669.0    233631.0      10932
# 3   159828861    359  PL 2155500   1009039.0    176368.0      13827
# 4   159834533    352  PL 1401000    986229.0    148311.0      18184
#
#    Community Districts  Borough Boundaries  City Council Districts  \
# 0                   11                   4                      51
# 1                   11                   4                      51
# 2                   49                   5                      35
# 3                   61                   2                      25
# 4                   21                   2                      45
#
#    Police Precincts
# 0                 8
# 1                10
# 2                23
# 3                40
# 4                35

# %%
# export the new dfs into csv files
arrests_df.to_csv('Data/NYPD_Arrests_Data_cleaned.csv', index=False)
refs_df.to_csv('Data/Reference_Data.csv', index=False)
